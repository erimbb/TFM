# %%
import maboss
# Out:
# <script type="text/javascript" id="colomoto-setup-9713362" class="to-be-removed">
#         if (typeof Jupyter != 'undefined') {
#
# function detect_import(cell, module) {
#     var code = cell.get_text();
#     code = code.replace(/\\\n/g, "");
#     var lines = code.split("\n");
#     var r_simple = new RegExp("^("+module+")$");
#     var r_alias = new RegExp("^"+module+"\\s+as\\s+(\\w+)$");
#     for (var i = 0; i < lines.length; ++i) {
#         if (/^import\s/.test(lines[i])) {
#             code = lines[i].substr(7);
#             var parts = code.split(",")
#             for (var j = 0; j < parts.length; ++j) {
#                 code = parts[j].trim();
#                 var m = code.match(r_simple);
#                 if (!m) {
#                     m = code.match(r_alias);
#                 }
#                 if (m) {
#                     return m[1];
#                 }
#             }
#         }
#     }
#     return module;
# }
#
# ...

# %% [markdown]
# # Sustitució termes GO per fenotips afegits manualment

# %%
model3 = maboss.load("model_3.bnd", "model_3.cfg")
res3 = model3.run()
res3.plot_piechart()
res3.plot_trajectory()

# %% [markdown]
# # Juntar nodes PAK3 i PAK4 / ARHGEF11 i ARHGEF12

# %%
mod4 = maboss.load("model_4.bnd", "model_4.cfg")
res4 = mod4.run()
res4.plot_piechart()
res4.plot_trajectory()

# %% [markdown]
# # Abstracció dels components dels complexos i eliminació d'apoptosi

# %%
mod5 = maboss.load("model_5.bnd", "model_5.cfg")
res5 = mod5.run()
res5.plot_piechart()
res5.plot_trajectory()

# %% [markdown]
# # Estudi de sensibilitat: probabilitats de baixada i pujada

# %%
mod6 = maboss.load("model_6.bnd", "model_6.cfg")
res6 = mod6.run()
res6.plot_piechart()
res6.plot_trajectory()

# %% [markdown]
# # Estudi de sensibilitat: afegir MYPT_input

# %%
mod = maboss.load("model_base.bnd", "model_base.cfg")
res = mod.run()
res.plot_piechart()
res.plot_trajectory()

# %% [markdown]
# # Guardar trajectòries

# %%
traj_3 = res3.get_states_probtraj()
traj_4 = res4.get_states_probtraj()
traj_5 = res5.get_states_probtraj()
traj_6 = res6.get_states_probtraj()
# traj_base = res.get_states_probtraj()

# %%
import os
os.makedirs('trajectories_proves', exist_ok=True)  
traj_3.to_csv('trajectories_proves/probtraj_3.csv', index=True)
traj_4.to_csv('trajectories_proves/probtraj_4.csv', index=True)
traj_5.to_csv('trajectories_proves/probtraj_5.csv', index=True)
traj_6.to_csv('trajectories_proves/probtraj_6.csv', index=True)
# traj_base.to_csv('trajectories_proves/probtraj_base.csv', index=True)
